# %%
import torch

print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("Device name:", torch.cuda.get_device_name(0))
    print("CUDA version:", torch.version.cuda)
    
    # Тестовая операция
    x = torch.rand(5, 3).cuda()
    print("Test tensor on GPU:", x)
else:
    print("CUDA not available")
# Out:
# CUDA available: True
# Device name: NVIDIA GeForce RTX 5070
# CUDA version: 12.6
# Test tensor on GPU:
# c:\Users\Andrey\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\cuda\__init__.py:435: UserWarning:
#     Found GPU0 NVIDIA GeForce RTX 5070 which is of cuda capability 12.0.
#     Minimum and Maximum cuda capability supported by this version of PyTorch is
#     (5.0) - (9.0)
#
#   queued_call()
# c:\Users\Andrey\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\cuda\__init__.py:435: UserWarning:
#     Please install PyTorch with a following CUDA
#     configurations:  12.8 13.0 following instructions at
#     https://pytorch.org/get-started/locally/
#
#   queued_call()
# c:\Users\Andrey\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\cuda\__init__.py:435: UserWarning:
# NVIDIA GeForce RTX 5070 with CUDA capability sm_120 is not compatible with the current PyTorch installation.
# The current PyTorch install supports CUDA capabilities sm_50 sm_60 sm_61 sm_70 sm_75 sm_80 sm_86 sm_90.
# If you want to use the NVIDIA GeForce RTX 5070 GPU with PyTorch, please check the instructions at https://pytorch.org/get-started/locally/
#
#   queued_call()
# ---------------------------------------------------------------------------
# AcceleratorError                          Traceback (most recent call last)
# Cell In[1], line 10
#       8     # Тестовая операция
#       9     x = torch.rand(5, 3).cuda()
# ---> 10     print("Test tensor on GPU:", x)
#      11 else:
#      12     print("CUDA not available")
#
# File c:\Users\Andrey\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_tensor.py:573, in Tensor.__repr__(self, tensor_contents)
#     569     return handle_torch_function(
#     570         Tensor.__repr__, (self,), self, tensor_contents=tensor_contents
#     571     )
#     572 # All strings are unicode in Python 3.
# --> 573 return torch._tensor_str._str(self, tensor_contents=tensor_contents)
#
# File c:\Users\Andrey\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_tensor_str.py:724, in _str(self, tensor_contents)
#     722 with torch.no_grad(), torch.utils._python_dispatch._disable_current_modes():
#     723     guard = torch._C._DisableFuncTorch()  # noqa: F841
# --> 724     return _str_intern(self, tensor_contents=tensor_contents)
#
# File c:\Users\Andrey\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_tensor_str.py:643, in _str_intern(inp, tensor_contents)
#     641                     tensor_str = _tensor_str(self.to_dense(), indent)
#     642                 else:
# --> 643                     tensor_str = _tensor_str(self, indent)
#     645 if self.layout != torch.strided:
#     646     suffixes.append("layout=" + str(self.layout))
#
# File c:\Users\Andrey\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_tensor_str.py:375, in _tensor_str(self, indent)
#     371     return _tensor_str_with_formatter(
#     372         self, indent, summarize, real_formatter, imag_formatter
#     373     )
#     374 else:
# --> 375     formatter = _Formatter(get_summarized_data(self) if summarize else self)
#     376     return _tensor_str_with_formatter(self, indent, summarize, formatter)
#
# File c:\Users\Andrey\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_tensor_str.py:155, in _Formatter.__init__(self, tensor)
#     146 if tensor.dtype == torch.float4_e2m1fn_x2:  # type: ignore[attr-defined]
#     147     # torch.float4_e2m1fn_x2 is special and does not support the casts necessary
#     148     # to print it, we choose to display the uint8 representation here for
#     149     # convenience of being able to print a tensor.
#     150     # TODO(#146647): extend this to other dtypes without casts defined, such
#     151     # as the bits, uint1..7 and int1..7 dtypes.
#     152     tensor_view = tensor_view.view(torch.uint8)
#     154 nonzero_finite_vals = torch.masked_select(
# --> 155     tensor_view, torch.isfinite(tensor_view) & tensor_view.ne(0)
#     156 )
#     158 if nonzero_finite_vals.numel() == 0:
#     159     # no valid number, do nothing
#     160     return
#
# AcceleratorError: CUDA error: no kernel image is available for execution on the device
# Search for `cudaErrorNoKernelImageForDevice' in https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html for more information.
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
